# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv("smartphone-usage-and-addiction-prediction/versions/1/Smartphone_Usage_And_Addiction_Analysis_7500_Rows.csv")
ds = df.drop(columns=["transaction_id","user_id"])
ds = pd.DataFrame(ds)
ds['addiction_level'] = ds['addiction_level'].fillna('none')
ds.head()
# Out:
#    age gender  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0   21   Male                     3.23                2.01          0.89
# 1   24  Other                     5.09                3.81          2.24
# 2   31  Other                     6.06                1.36          3.83
# 3   32  Other                     7.83                5.85          1.51
# 4   25   Male                     9.96                5.92          3.42
#
#    work_study_hours  sleep_hours  notifications_per_day  app_opens_per_day  \
# 0              4.55         7.55                    248                154
# 1              4.44         7.66                    127                 71
# 2              2.35         4.92                     44                106
# 3              3.54         8.23                    178                107
# 4              5.27         6.21                    136                177
#
#    weekend_screen_time stress_level academic_work_impact addiction_level  \
# ...

# %%
ds.describe
# Out:
# <bound method NDFrame.describe of       age  gender  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0      21    Male                     3.23                2.01          0.89
# 1      24   Other                     5.09                3.81          2.24
# 2      31   Other                     6.06                1.36          3.83
# 3      32   Other                     7.83                5.85          1.51
# 4      25    Male                     9.96                5.92          3.42
# ...   ...     ...                      ...                 ...           ...
# 7495   26   Other                     9.85                1.75          3.13
# 7496   35    Male                     5.67                2.33          2.76
# 7497   22  Female                     9.99                3.61          1.09
# 7498   23    Male                     8.74                1.59          0.07
# 7499   27  Female                    10.04                5.40          0.73
#
# ...

# %%
ds.describe()
# Out:
#                age  daily_screen_time_hours  social_media_hours  gaming_hours  \
# count  7500.000000              7500.000000         7500.000000   7500.000000
# mean     26.568800                 7.499912            3.273484      2.014183
# std       5.197108                 2.609188            1.585342      1.146039
# min      18.000000                 3.000000            0.500000      0.000000
# 25%      22.000000                 5.220000            1.910000      1.020000
# 50%      27.000000                 7.525000            3.270000      2.040000
# 75%      31.000000                 9.810000            4.630000      2.990000
# max      35.000000                12.000000            6.000000      4.000000
#
#        work_study_hours  sleep_hours  notifications_per_day  \
# count       7500.000000  7500.000000            7500.000000
# mean           3.242420     6.737561             134.257333
# std            1.600765     1.283605              66.586883
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      transaction_id user_id  age  gender  daily_screen_time_hours  \
# 0          TXN00001  U00001   21    Male                     3.23
# 1          TXN00002  U00002   24   Other                     5.09
# 2          TXN00003  U00003   31   Other                     6.06
# 3          TXN00004  U00004   32   Other                     7.83
# 4          TXN00005  U00005   25    Male                     9.96
# ...             ...     ...  ...     ...                      ...
# 7495       TXN07496  U07496   26   Other                     9.85
# 7496       TXN07497  U07497   35    Male                     5.67
# 7497       TXN07498  U07498   22  Female                     9.99
# 7498       TXN07499  U07499   23    Male                     8.74
# 7499       TXN07500  U07500   27  Female                    10.04
#
#       social_media_hours  gaming_hours  work_study_hours  sleep_hours  \
# ...

# %%
ds.isnull().sum()
# Out:
# age                        0
# gender                     0
# daily_screen_time_hours    0
# social_media_hours         0
# gaming_hours               0
# work_study_hours           0
# sleep_hours                0
# notifications_per_day      0
# app_opens_per_day          0
# weekend_screen_time        0
# stress_level               0
# academic_work_impact       0
# addiction_level            0
# addicted_label             0
# dtype: int64

# %%
sns.distplot(df['age'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['daily_screen_time_hours'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\3841478843.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['daily_screen_time_hours'])
# <Axes: xlabel='daily_screen_time_hours', ylabel='Density'>

# %%
sns.distplot(df['social_media_hours'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\3684916890.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['social_media_hours'])
# <Axes: xlabel='social_media_hours', ylabel='Density'>

# %%
sns.distplot(df['gaming_hours'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\3751367247.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['gaming_hours'])
# <Axes: xlabel='gaming_hours', ylabel='Density'>

# %%
sns.distplot(df['work_study_hours'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\2434611732.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['work_study_hours'])
# <Axes: xlabel='work_study_hours', ylabel='Density'>

# %%
sns.distplot(df['sleep_hours'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\2489400932.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sleep_hours'])
# <Axes: xlabel='sleep_hours', ylabel='Density'>

# %%
sns.distplot(df['notifications_per_day'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\1799089669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['notifications_per_day'])
# <Axes: xlabel='notifications_per_day', ylabel='Density'>

# %%
sns.distplot(df['app_opens_per_day'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\1619302336.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['app_opens_per_day'])
# <Axes: xlabel='app_opens_per_day', ylabel='Density'>

# %%
sns.distplot(df['weekend_screen_time'])
# Out:
# C:\Users\MADHUSUDAN\AppData\Local\Temp\ipykernel_480\2131860146.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['weekend_screen_time'])
# <Axes: xlabel='weekend_screen_time', ylabel='Density'>

# %%
###OUTLIER ANALYSIS
import matplotlib.pyplot as plt

# %%
out_age=plt.boxplot(df['age'])

# %%
out_DST=plt.boxplot(df['daily_screen_time_hours'])

# %%
out_smh=plt.boxplot(df['social_media_hours'])

# %%
out_gh=plt.boxplot(df['gaming_hours'])

# %%
out_ph=plt.boxplot(df['work_study_hours'])

# %%
out_sh=plt.boxplot(df['sleep_hours'])

# %%
out_npd=plt.boxplot(df['notifications_per_day'])

# %%
out_app=plt.boxplot(df['app_opens_per_day'])

# %%
out_week=plt.boxplot(df['weekend_screen_time'])

# %%
ds = ds.drop(columns=["stress_level","gender","academic_work_impact","addiction_level"])

# %%
coor=ds.corr()

# %%
coor
# Out:
#                               age  daily_screen_time_hours  \
# age                      1.000000                 0.012767
# daily_screen_time_hours  0.012767                 1.000000
# social_media_hours       0.000342                 0.010321
# gaming_hours            -0.026107                 0.001140
# work_study_hours        -0.017147                 0.003108
# sleep_hours             -0.007462                 0.019343
# notifications_per_day    0.000387                 0.000811
# app_opens_per_day       -0.002276                 0.024448
# weekend_screen_time      0.015286                 0.964295
# addicted_label           0.004220                 0.577112
#
#                          social_media_hours  gaming_hours  work_study_hours  \
# age                                0.000342     -0.026107         -0.017147
# daily_screen_time_hours            0.010321      0.001140          0.003108
# social_media_hours                 1.000000     -0.000902         -0.002580
# ...

# %%
fun, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(coor, mask=np.zeros_like(coor, dtype=np.bool), cmap=sns.diverging_palette(200, 20, as_cmap=True),
            square=True, ax=ax,annot=True)
# Out:
# <Axes: >
