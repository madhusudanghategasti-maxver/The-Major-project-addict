# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

# %%
ds = pd.read_csv("smartphone-usage-and-addiction-prediction/ve")
# Out:
#    age gender  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0   21   Male                     3.23                2.01          0.89
# 1   24  Other                     5.09                3.81          2.24
# 2   31  Other                     6.06                1.36          3.83
# 3   32  Other                     7.83                5.85          1.51
# 4   25   Male                     9.96                5.92          3.42
#
#    work_study_hours  sleep_hours  notifications_per_day  app_opens_per_day  \
# 0              4.55         7.55                    248                154
# 1              4.44         7.66                    127                 71
# 2              2.35         4.92                     44                106
# 3              3.54         8.23                    178                107
# 4              5.27         6.21                    136                177
#
#    weekend_screen_time stress_level academic_work_impact addiction_level  \
# ...

# %%
# Out:
# float64
# [1. 2. 0.]
#       age  gender  daily_screen_time_hours  social_media_hours  gaming_hours  \
# 0      21     1.0                     3.23                2.01          0.89
# 1      24     2.0                     5.09                3.81          2.24
# 2      31     2.0                     6.06                1.36          3.83
# 3      32     2.0                     7.83                5.85          1.51
# 4      25     1.0                     9.96                5.92          3.42
# ...   ...     ...                      ...                 ...           ...
# 7495   26     2.0                     9.85                1.75          3.13
# 7496   35     1.0                     5.67                2.33          2.76
# 7497   22     0.0                     9.99                3.61          1.09
# 7498   23     1.0                     8.74                1.59          0.07
# 7499   27     0.0                    10.04                5.40          0.73
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 cat_aca = ['Yes', 'No']
#       2 enc1=OrdinalEncoder(categories=[cat_aca])
# ----> 3 ds['academic_work_impact'] = enc1.fit_transform(ds[['academic_work_impact']])
#       4 cat_str = ['Low', 'Medium', 'High']
#       5 enc2=OrdinalEncoder(categories=[cat_str])
#       6 ds['stress_level'] = enc2.fit_transform(ds[['stress_level']])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
# ...

# %%
ds.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6681 entries, 2 to 7499
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      6681 non-null   int64
#  1   gender                   6681 non-null   str
#  2   daily_screen_time_hours  6681 non-null   float64
#  3   social_media_hours       6681 non-null   float64
#  4   gaming_hours             6681 non-null   float64
#  5   work_study_hours         6681 non-null   float64
#  6   sleep_hours              6681 non-null   float64
#  7   notifications_per_day    6681 non-null   int64
#  8   app_opens_per_day        6681 non-null   int64
#  9   weekend_screen_time      6681 non-null   float64
#  10  stress_level             6681 non-null   float64
#  11  academic_work_impact     6681 non-null   float64
#  12  addiction_level          6681 non-null   float64
#  13  addicted_label           6681 non-null   int64
# ...
